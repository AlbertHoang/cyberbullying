# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import re
import json
from os.path import join
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
float_formatter = "{:.4f}".format
np.set_printoptions(formatter={'float_kind':float_formatter})
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
## Runing on Colab
## /content/drive/MyDrive/git/cyberbullying/input/hate_speech/MMHS150K_GT.json
dataset_directory = '/content/drive/MyDrive/git/cyberbullying/input/hate_speech' 
img_txt_directory = 
img_resized_directory = 
splits_directory = 

## Runing on Local
dataset_directory = '/content/drive/MyDrive/git/cyberbullying/input/hate_speech' 
img_txt_directory = 
img_resized_directory = 
splits_directory =

# %%
with open(join(dataset_directory,'MMHS150K_GT.json')) as json_file:
    hate_speech_data = json.load(json_file)

# %%
hate_speech_ori = pd.DataFrame(hate_speech_data)

# %%
hate_speech_ori.head(5)
# Out:
#                                           1114679353714016256  ...                                1114653514364530691
# img_url     http://pbs.twimg.com/tweet_video_thumb/D3gi9MH...  ...     http://pbs.twimg.com/media/D3gLdL0W0AENzVJ.jpg
# labels                                              [4, 1, 3]  ...                                          [0, 0, 3]
# tweet_url   https://twitter.com/user/status/11146793537140...  ...  https://twitter.com/user/status/11146535143645...
# tweet_text       @FriskDontMiss Nigga https://t.co/cAsaLWEpue  ...  This nigga Joe Budden said thanos got a galact...
# labels_str                      [Religion, Racist, Homophobe]  ...                      [NotHate, NotHate, Homophobe]
#
# [5 rows x 149823 columns]

# %%
hate_speech_ori = hate_speech_ori.transpose()
hate_speech_ori=hate_speech_ori.reset_index()
hate_speech_ori.rename(columns={"index": "user_id"},inplace=True)

# %%
hate_speech_ori.head(5)
# Out:
#                user_id  ...                         labels_str
# 0  1114679353714016256  ...      [Religion, Racist, Homophobe]
# 1  1063020048816660480  ...  [OtherHate, OtherHate, OtherHate]
# 2  1108927368075374593  ...        [NotHate, NotHate, NotHate]
# 3  1114558534635618305  ...         [Racist, NotHate, NotHate]
# 4  1035252480215592966  ...          [Racist, NotHate, Racist]
#
# [5 rows x 6 columns]

# %%
hate_speech_ori['tweet_url'][0]
# Out:
# 'https://twitter.com/user/status/1114679353714016256'

# %%
hate_speech_df = hate_speech_ori.copy()

# %% [markdown]
# # General

# %% [markdown]
# ##Number of records in the dataset, split between labels.

# %%
not_hate=0
racist=0
sexist=0
homophobe=0
religion=0
other_hate=0
for i in hate_speech_df['labels']:
    for j in i:
        if j==0:
            not_hate+=1
        elif j==1:
            racist+=1
        elif j==2:
            sexist+=1
        elif j==3:
            homophobe+=1
        elif j==4:
            religion+=1
        else:
            other_hate+=1
label_li=['not_hate','racist','sexist','homophobe','religion','other_hate']
label_li_value=[not_hate,racist,sexist,homophobe,religion,other_hate]

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title("Tweet distribution based on labels")
ax.pie(label_li_value,labels=label_li,autopct='%1.2f%%')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Number of records with text, image, and metadata (what percentage for each modality)

# %%
print("Total number for tweets are: ",len(hate_speech_df))

# %%
print("Total number for tweets are: ",len(hate_speech_df[]))
